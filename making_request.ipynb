# %%
# Install Dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in ./.venv/lib/python3.13/site-packages (1.3.0)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.13/site-packages (1.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.13/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./.venv/lib/python3.13/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx2<3,>=2.0.0 in ./.venv/lib/python3.13/site-packages (from anthropic) (2.12.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.13/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.13/site-packages (from anthropic) (2.13.5)
# Requirement already satisfied: sniffio<2,>=1 in ./.venv/lib/python3.13/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./.venv/lib/python3.13/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.19)
# Requirement already satisfied: httpcore2==2.12.0 in ./.venv/lib/python3.13/site-packages (from httpx2<3,>=2.0.0->anthropic) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in ./.venv/lib/python3.13/site-packages (from httpx2<3,>=2.0.0->anthropic) (0.10.4)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.13/site-packages (from httpcore2==2.12.0->httpx2<3,>=2.0.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in ./.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load Env
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Make a Request

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )

    return message.content[0].text

# %%
# Make a starting list of messages

# Add in the initial user question of "Define quantum computing in one sentence"

# Pass the list of messages into 'chat' to get an answer

# Take the answer and add it as an assistant message into our list

# Add in the user's follow-up question

# Call chat again with the list of messages to get a final answer
